# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
## import seaborn
import seaborn as sns
import pandas as pd
import warnings
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("final_tripdata_new (1).csv",encoding="latin-1")#ISO-8859-1
data
# Out:
#       Unnamed: 0           ride_id  rideable_type           started_at  \
# 0        4993971  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28
# 1        2539858  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49
# 2        1084867  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06
# 3        5202426  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30
# 4        2241145  68163A1203766B61   classic_bike  2021-05-30 13:36:56
# ...          ...               ...            ...                  ...
# 9995     3608870  A793AD6E0E1F80BE    docked_bike  2020-10-05 13:58:43
# 9996     4653300  D7F40C4AD674B7A6   classic_bike  2021-05-28 11:48:33
# 9997      963750  2CB92E8592E117F7    docked_bike  2021-06-20 14:45:56
# 9998       91974  0445393F376408CE    docked_bike  2021-05-23 12:58:52
# 9999     4405949  CC7844CD89E52FAC    docked_bike  2021-06-11 14:03:02
#
#                  ended_at           start_station_name start_station_id  \
# ...

# %%
data.head()
# Out:
#    Unnamed: 0           ride_id  rideable_type           started_at  \
# 0     4993971  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28
# 1     2539858  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49
# 2     1084867  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06
# 3     5202426  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30
# 4     2241145  68163A1203766B61   classic_bike  2021-05-30 13:36:56
#
#               ended_at           start_station_name start_station_id  \
# 0  2020-08-13 13:55:29     Wells St & Evergreen Ave              291
# 1  2020-10-09 12:47:34      Streeter Dr & Grand Ave               35
# 2  2020-11-06 17:46:46      Sedgwick St & North Ave              118
# 3  2021-06-15 01:00:47  Desplaines St & Randolph St            15535
# 4  2021-05-30 13:43:25       Woodlawn Ave & 55th St     TA1307000164
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# ...

# %%
data.sample(25)
# Out:
#       Unnamed: 0           ride_id  rideable_type           started_at  \
# 1234     4994878  E7D755BA515880F4    docked_bike  2020-07-18 08:38:10
# 8736     4062794  BC91D85E2E493EED  electric_bike  2020-10-11 11:32:31
# 96       5458860  FD610AEDA0A8D63D    docked_bike  2020-10-06 16:46:27
# 3806     1401647  411AAB9F06822C70  electric_bike  2021-06-16 12:33:16
# 627       904155  29F88F73B74192C5  electric_bike  2021-05-14 14:32:52
# 3584     2875619  8581B038EF1C3C39   classic_bike  2021-06-08 19:39:30
# 9424     1964012  5B3BC739015D5A5B   classic_bike  2021-03-22 14:38:41
# 7379     3262104  977891FE90E6C4FD   classic_bike  2021-06-29 15:37:55
# 6835     4492141  D073954FEF2D3B5C    docked_bike  2020-07-24 13:40:25
# 3142     1692143  4E97886414C393B3    docked_bike  2020-10-31 17:47:49
# 4658     1227527  390250E56725DCC1  electric_bike  2021-05-25 13:23:26
# 3424     5190000  F0EA5A39E06F675B  electric_bike  2020-11-07 14:30:31
# ...

# %%
data.shape
# Out:
# (10000, 17)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'day_week_start', 'duration', 'distance'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          10000 non-null  int64
#  1   ride_id             10000 non-null  object
#  2   rideable_type       10000 non-null  object
#  3   started_at          10000 non-null  object
#  4   ended_at            10000 non-null  object
#  5   start_station_name  9503 non-null   object
#  6   start_station_id    9501 non-null   object
#  7   end_station_name    9452 non-null   object
#  8   end_station_id      9450 non-null   object
#  9   start_lat           10000 non-null  float64
#  10  start_lng           10000 non-null  float64
#  11  end_lat             10000 non-null  float64
#  12  end_lng             10000 non-null  float64
#  13  member_casual       10000 non-null  object
#  14  day_week_start      10000 non-null  float64
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0              int64
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# day_week_start        float64
# duration              float64
# distance              float64
# dtype: object

# %%
data.describe()
# Out:
#          Unnamed: 0     start_lat     start_lng       end_lat       end_lng  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   2.770343e+06     41.903235    -87.644840     41.866114    -87.566410
# std    1.593198e+06      0.043200      0.025615      1.257363      2.628435
# min    1.268000e+03     41.648501    -87.780000      0.000000    -87.774519
# 25%    1.398568e+06     41.882091    -87.658813     41.882200    -87.659172
# 50%    2.780976e+06     41.898969    -87.641417     41.900000    -87.642705
# 75%    4.158111e+06     41.929143    -87.627754     41.929567    -87.627844
# max    5.515072e+06     42.070000    -87.530000     42.070000      0.000000
#
#        day_week_start      duration       distance
# count    10000.000000  1.000000e+04   10000.000000
# mean         4.125600  2.099192e+04   22330.345218
# std          2.082032  1.508842e+06   19705.707874
# min          1.000000 -9.003341e+07      -1.000000
# ...

# %%
data.drop("Unnamed: 0",inplace=True,axis=1)

# %%
data.shape
# Out:
# (10000, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             10000 non-null  object
#  1   rideable_type       10000 non-null  object
#  2   started_at          10000 non-null  object
#  3   ended_at            10000 non-null  object
#  4   start_station_name  9503 non-null   object
#  5   start_station_id    9501 non-null   object
#  6   end_station_name    9452 non-null   object
#  7   end_station_id      9450 non-null   object
#  8   start_lat           10000 non-null  float64
#  9   start_lng           10000 non-null  float64
#  10  end_lat             10000 non-null  float64
#  11  end_lng             10000 non-null  float64
#  12  member_casual       10000 non-null  object
#  13  day_week_start      10000 non-null  float64
#  14  duration            10000 non-null  float64
# ...

# %%
data[data['duration']<=0]
# Out:
#                   ride_id  rideable_type           started_at  \
# 63       1EEA975F1E95F972    docked_bike  2020-07-14 18:19:28
# 470      9C432172669C65D3    docked_bike  2020-08-11 17:31:05
# 1041     194A62C72BFFC1CC    docked_bike  2020-07-12 19:38:53
# 1413     8ADAD8E503067DF4    docked_bike  2020-09-11 11:04:59
# 1816     F76C6D689F531760    docked_bike  2020-09-19 17:50:33
# 1976     13E5F677800F8151    docked_bike  2020-11-04 16:46:50
# 2217     22F590BA5AD3507D    docked_bike  2020-10-11 18:19:10
# 2673     CE56B8ECFE72DA73    docked_bike  2020-11-08 12:39:15
# 4398     D483FF80E38325F3    docked_bike  2020-09-07 16:56:31
# 5374     DF8F15B26070E691    docked_bike  2020-08-21 17:31:38
# 7500     3F6EE6FD95FAE8A6    docked_bike  2020-07-05 17:02:23
# 7828     BF44E3263CBA82D4  electric_bike  2020-10-16 16:44:56
# 8059     839603DADE7B3F6E    docked_bike  2020-10-13 09:31:00
# 8254     A9C677AB30627686    docked_bike  2020-04-15 19:15:44
# ...

# %%
# droppog the duration column which is having the negative value
data.drop(data.index[data['duration']<=0],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9980 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             9980 non-null   object
#  1   rideable_type       9980 non-null   object
#  2   started_at          9980 non-null   object
#  3   ended_at            9980 non-null   object
#  4   start_station_name  9483 non-null   object
#  5   start_station_id    9481 non-null   object
#  6   end_station_name    9432 non-null   object
#  7   end_station_id      9430 non-null   object
#  8   start_lat           9980 non-null   float64
#  9   start_lng           9980 non-null   float64
#  10  end_lat             9980 non-null   float64
#  11  end_lng             9980 non-null   float64
#  12  member_casual       9980 non-null   object
#  13  day_week_start      9980 non-null   float64
#  14  duration            9980 non-null   float64
# ...

# %%
data[data['duration']<=0]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, day_week_start, duration, distance]
# Index: []

# %%
data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06  2020-11-06 17:46:46
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
# 4  68163A1203766B61   classic_bike  2021-05-30 13:36:56  2021-05-30 13:43:25
#
#             start_station_name start_station_id  \
# 0     Wells St & Evergreen Ave              291
# 1      Streeter Dr & Grand Ave               35
# 2      Sedgwick St & North Ave              118
# 3  Desplaines St & Randolph St            15535
# 4       Woodlawn Ave & 55th St     TA1307000164
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0             Paulina St & 18th St            205  41.906724 -87.634830
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9980 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             9980 non-null   object
#  1   rideable_type       9980 non-null   object
#  2   started_at          9980 non-null   object
#  3   ended_at            9980 non-null   object
#  4   start_station_name  9483 non-null   object
#  5   start_station_id    9481 non-null   object
#  6   end_station_name    9432 non-null   object
#  7   end_station_id      9430 non-null   object
#  8   start_lat           9980 non-null   float64
#  9   start_lng           9980 non-null   float64
#  10  end_lat             9980 non-null   float64
#  11  end_lng             9980 non-null   float64
#  12  member_casual       9980 non-null   object
#  13  day_week_start      9980 non-null   float64
#  14  duration            9980 non-null   float64
# ...

# %%
data[data['distance']<0]
# Out:
#                ride_id rideable_type           started_at  \
# 3140  43CF316C525AAFBA   docked_bike  2020-06-20 10:44:52
# 3323  28B3154DDF729877  classic_bike  2021-06-22 06:46:32
# 3587  80A0002053113EDA   docked_bike  2020-11-11 17:35:39
# 4433  1339B90E5A59FC60   docked_bike  2020-10-08 15:46:32
# 7826  EA4E81B09C9E6464   docked_bike  2020-08-29 07:50:24
# 8155  990B129251FBD5CB   docked_bike  2020-07-12 15:34:44
# 8569  388AF4A83E826C22   docked_bike  2020-07-04 10:59:50
# 9659  9956687812E9581F   docked_bike  2020-10-05 16:37:13
# 9866  24B4286B25D814A2   docked_bike  2020-08-28 10:53:08
#
#                  ended_at          start_station_name start_station_id  \
# 3140  2020-06-21 11:44:46       Western Ave & 21st St              203
# 3323  2021-06-22 15:05:25         2112 W Peterson Ave     KA1504000155
# 3587  2020-11-11 20:41:40     Wood St & Milwaukee Ave               61
# 4433  2020-10-09 14:08:45       Calumet Ave & 51st St              415
# ...

# %%
# droppog the distance column which is having the negative value
data.drop(data.index[data['distance']<0],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9971 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             9971 non-null   object
#  1   rideable_type       9971 non-null   object
#  2   started_at          9971 non-null   object
#  3   ended_at            9971 non-null   object
#  4   start_station_name  9474 non-null   object
#  5   start_station_id    9472 non-null   object
#  6   end_station_name    9432 non-null   object
#  7   end_station_id      9430 non-null   object
#  8   start_lat           9971 non-null   float64
#  9   start_lng           9971 non-null   float64
#  10  end_lat             9971 non-null   float64
#  11  end_lng             9971 non-null   float64
#  12  member_casual       9971 non-null   object
#  13  day_week_start      9971 non-null   float64
#  14  duration            9971 non-null   float64
# ...

# %%
data[data['distance']<0]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, day_week_start, duration, distance]
# Index: []

# %%
data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06  2020-11-06 17:46:46
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
# 4  68163A1203766B61   classic_bike  2021-05-30 13:36:56  2021-05-30 13:43:25
#
#             start_station_name start_station_id  \
# 0     Wells St & Evergreen Ave              291
# 1      Streeter Dr & Grand Ave               35
# 2      Sedgwick St & North Ave              118
# 3  Desplaines St & Randolph St            15535
# 4       Woodlawn Ave & 55th St     TA1307000164
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0             Paulina St & 18th St            205  41.906724 -87.634830
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9971 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             9971 non-null   object
#  1   rideable_type       9971 non-null   object
#  2   started_at          9971 non-null   object
#  3   ended_at            9971 non-null   object
#  4   start_station_name  9474 non-null   object
#  5   start_station_id    9472 non-null   object
#  6   end_station_name    9432 non-null   object
#  7   end_station_id      9430 non-null   object
#  8   start_lat           9971 non-null   float64
#  9   start_lng           9971 non-null   float64
#  10  end_lat             9971 non-null   float64
#  11  end_lng             9971 non-null   float64
#  12  member_casual       9971 non-null   object
#  13  day_week_start      9971 non-null   float64
#  14  duration            9971 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# ride_id                 0
# rideable_type           0
# started_at              0
# ended_at                0
# start_station_name    497
# start_station_id      499
# end_station_name      539
# end_station_id        541
# start_lat               0
# start_lng               0
# end_lat                 0
# end_lng                 0
# member_casual           0
# day_week_start          0
# duration                0
# distance                0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 2076

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# day_week_start        0
# duration              0
# distance              0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, day_week_start, duration, distance]
# Index: []

# %%
data['day_week_start'].replace({1.0:'sunday',2.0:'monday',3.0:'tuesday',4.0:'wednesday',5.0:'thrusday',6.0:'friday',7.0:'saturday',8.0:'sunday'},inplace=True)

# %%
data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06  2020-11-06 17:46:46
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
# 4  68163A1203766B61   classic_bike  2021-05-30 13:36:56  2021-05-30 13:43:25
#
#             start_station_name start_station_id  \
# 0     Wells St & Evergreen Ave              291
# 1      Streeter Dr & Grand Ave               35
# 2      Sedgwick St & North Ave              118
# 3  Desplaines St & Randolph St            15535
# 4       Woodlawn Ave & 55th St     TA1307000164
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0             Paulina St & 18th St            205  41.906724 -87.634830
# ...

# %%
data=data.drop(['start_lat','start_lng','end_lat','end_lng'],axis=1)

# %%
data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06  2020-11-06 17:46:46
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
# 4  68163A1203766B61   classic_bike  2021-05-30 13:36:56  2021-05-30 13:43:25
#
#             start_station_name start_station_id  \
# 0     Wells St & Evergreen Ave              291
# 1      Streeter Dr & Grand Ave               35
# 2      Sedgwick St & North Ave              118
# 3  Desplaines St & Randolph St            15535
# 4       Woodlawn Ave & 55th St     TA1307000164
#
#                   end_station_name end_station_id member_casual  \
# 0             Paulina St & 18th St            205        member
# 1          Streeter Dr & Grand Ave             35        casual
# ...

# %%
data_member=data
data_causal=data
data_both=data

# %% [markdown]
# # Process

# %%
data.describe()
# Out:
#            duration       distance
# count  9.208000e+03    9208.000000
# mean   3.191490e+04   21994.632308
# std    1.261398e+06   19271.945098
# min    1.000000e+00       0.000000
# 25%    7.980000e+02    8892.040000
# 50%    1.610000e+03   17110.955000
# 75%    5.330250e+03   29761.717500
# max    6.985961e+07  191547.550000

# %%
data['member_casual'].value_counts()
# Out:
# member_casual
# member    5591
# casual    3617
# Name: count, dtype: int64

# %%
data['distance'].mean()
# Out:
# 21994.632307775846

# %%
data['distance'].max()
# Out:
# 191547.55

# %%
data['day_week_start'].mode()
# Out:
# 0    saturday
# Name: day_week_start, dtype: object

# %%
data.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06  2020-11-06 17:46:46
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
# 4  68163A1203766B61   classic_bike  2021-05-30 13:36:56  2021-05-30 13:43:25
#
#             start_station_name start_station_id  \
# 0     Wells St & Evergreen Ave              291
# 1      Streeter Dr & Grand Ave               35
# 2      Sedgwick St & North Ave              118
# 3  Desplaines St & Randolph St            15535
# 4       Woodlawn Ave & 55th St     TA1307000164
#
#                   end_station_name end_station_id member_casual  \
# 0             Paulina St & 18th St            205        member
# 1          Streeter Dr & Grand Ave             35        casual
# ...

# %%
data['end_station_name'].value_counts()
# Out:
# end_station_name
# Streeter Dr & Grand Ave    123
# Millennium Park             89
# Clark St & Elm St           81
# Broadway & Barry Ave        81
# Wells St & Concord Ln       80
#                           ...
# Millard Ave & 26th St        1
# Vernon Ave & 107th St        1
# Prospect Sq & 91st St        1
# Normal Ave & Archer Ave      1
# 2112 W Peterson Ave          1
# Name: count, Length: 565, dtype: int64

# %%
data['start_station_name'].value_counts()
# Out:
# start_station_name
# Streeter Dr & Grand Ave       126
# Lake Shore Dr & North Blvd     96
# Theater on the Lake            92
# Clark St & Elm St              86
# Lake Shore Dr & Monroe St      78
#                              ...
# Albany Ave & 26th St            1
# Stony Island Ave & 75th St      1
# Ellis Ave & 83rd St             1
# Hoyne Ave & Balmoral Ave        1
# Commercial Ave & 83rd St        1
# Name: count, Length: 559, dtype: int64

# %%
data['rideable_type'].value_counts()
# Out:
# rideable_type
# docked_bike      5558
# classic_bike     2363
# electric_bike    1287
# Name: count, dtype: int64

# %%
data.head(4)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike  2020-11-06 17:35:06  2020-11-06 17:46:46
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
#
#             start_station_name start_station_id            end_station_name  \
# 0     Wells St & Evergreen Ave              291        Paulina St & 18th St
# 1      Streeter Dr & Grand Ave               35     Streeter Dr & Grand Ave
# 2      Sedgwick St & North Ave              118      Damen Ave & Pierce Ave
# 3  Desplaines St & Randolph St            15535  Kedzie Ave & Bryn Mawr Ave
#
#   end_station_id member_casual day_week_start  duration   distance
# 0            205        member       thrusday    3801.0   59446.72
# ...

# %%
data['day_week_start'].value_counts()
# Out:
# day_week_start
# saturday     1641
# sunday       1415
# friday       1385
# wednesday    1228
# tuesday      1214
# thrusday     1184
# monday       1141
# Name: count, dtype: int64

# %%
data.head(2)
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F   docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 1  75F3F6997F82F01C   docked_bike  2020-10-09 12:26:49  2020-10-09 12:47:34
#
#          start_station_name start_station_id         end_station_name  \
# 0  Wells St & Evergreen Ave              291     Paulina St & 18th St
# 1   Streeter Dr & Grand Ave               35  Streeter Dr & Grand Ave
#
#   end_station_id member_casual day_week_start  duration  distance
# 0            205        member       thrusday    3801.0  59446.72
# 1             35        casual         friday    2085.0      0.00

# %%
data_member=data[data['member_casual']=='member']

# %%
data_casual=data[data['member_casual']=='member']

# %%
data_member['distance'].mean()
# Out:
# 22362.791364693257

# %%
data_member.describe()
# Out:
#            duration       distance
# count  5.591000e+03    5591.000000
# mean   2.901588e+04   22362.791365
# std    1.319827e+06   18293.998666
# min    1.000000e+00       0.000000
# 25%    6.740000e+02    9516.790000
# 50%    1.222000e+03   17256.130000
# 75%    3.154000e+03   29974.260000
# max    6.976718e+07  134817.690000

# %%
data_casual.describe()
# Out:
#            duration       distance
# count  5.591000e+03    5591.000000
# mean   2.901588e+04   22362.791365
# std    1.319827e+06   18293.998666
# min    1.000000e+00       0.000000
# 25%    6.740000e+02    9516.790000
# 50%    1.222000e+03   17256.130000
# 75%    3.154000e+03   29974.260000
# max    6.976718e+07  134817.690000

# %%
data_member.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
#
#             start_station_name start_station_id            end_station_name  \
# 0     Wells St & Evergreen Ave              291        Paulina St & 18th St
# 3  Desplaines St & Randolph St            15535  Kedzie Ave & Bryn Mawr Ave
#
#   end_station_id member_casual day_week_start  duration   distance
# 0            205        member       thrusday    3801.0   59446.72
# 3   KA1504000167        member        tuesday    7217.0  117106.31

# %%
data_casual.head(2)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike  2020-08-13 13:17:28  2020-08-13 13:55:29
# 3  F17EA7F23A221021  electric_bike  2021-06-15 00:28:30  2021-06-15 01:00:47
#
#             start_station_name start_station_id            end_station_name  \
# 0     Wells St & Evergreen Ave              291        Paulina St & 18th St
# 3  Desplaines St & Randolph St            15535  Kedzie Ave & Bryn Mawr Ave
#
#   end_station_id member_casual day_week_start  duration   distance
# 0            205        member       thrusday    3801.0   59446.72
# 3   KA1504000167        member        tuesday    7217.0  117106.31

# %%
data_member['rideable_type'].value_counts()
# Out:
# rideable_type
# docked_bike      3293
# classic_bike     1570
# electric_bike     728
# Name: count, dtype: int64

# %%
data_casual['rideable_type'].value_counts()
# Out:
# rideable_type
# docked_bike      3293
# classic_bike     1570
# electric_bike     728
# Name: count, dtype: int64

# %%
data_member['start_station_name'].value_counts()
# Out:
# start_station_name
# Clark St & Elm St                65
# Lake Shore Dr & North Blvd       51
# Desplaines St & Kinzie St        49
# Wells St & Huron St              48
# Theater on the Lake              48
#                                  ..
# Dodge Ave & Mulford St            1
# Princeton Ave & Garfield Blvd     1
# Milwaukee Ave & Cuyler Ave        1
# Malcolm X College                 1
# Leavitt St & Addison St           1
# Name: count, Length: 493, dtype: int64

# %%
data_casual['start_station_name'].value_counts()
# Out:
# start_station_name
# Clark St & Elm St                65
# Lake Shore Dr & North Blvd       51
# Desplaines St & Kinzie St        49
# Wells St & Huron St              48
# Theater on the Lake              48
#                                  ..
# Dodge Ave & Mulford St            1
# Princeton Ave & Garfield Blvd     1
# Milwaukee Ave & Cuyler Ave        1
# Malcolm X College                 1
# Leavitt St & Addison St           1
# Name: count, Length: 493, dtype: int64

# %%
data_member['end_station_name'].value_counts()
# Out:
# end_station_name
# Clark St & Elm St                61
# Broadway & Barry Ave             51
# Wells St & Concord Ln            48
# Wabash Ave & Roosevelt Rd        44
# Kingsbury St & Kinzie St         43
#                                  ..
# Kilbourn Ave & Irving Park Rd     1
# Lake Park Ave & 47th St           1
# Clark St & Columbia Ave           1
# Normal Ave & Archer Ave           1
# 2112 W Peterson Ave               1
# Name: count, Length: 497, dtype: int64

# %%
data_casual['end_station_name'].value_counts()
# Out:
# end_station_name
# Clark St & Elm St                61
# Broadway & Barry Ave             51
# Wells St & Concord Ln            48
# Wabash Ave & Roosevelt Rd        44
# Kingsbury St & Kinzie St         43
#                                  ..
# Kilbourn Ave & Irving Park Rd     1
# Lake Park Ave & 47th St           1
# Clark St & Columbia Ave           1
# Normal Ave & Archer Ave           1
# 2112 W Peterson Ave               1
# Name: count, Length: 497, dtype: int64

# %%
data_member['day_week_start'].value_counts()
# Out:
# day_week_start
# tuesday      851
# wednesday    841
# saturday     811
# friday       804
# monday       785
# thrusday     780
# sunday       719
# Name: count, dtype: int64

# %%
data_casual['day_week_start'].value_counts()
# Out:
# day_week_start
# tuesday      851
# wednesday    841
# saturday     811
# friday       804
# monday       785
# thrusday     780
# sunday       719
# Name: count, dtype: int64

# %%
from datetime import date

# %%
data['started_at']=pd.to_datetime(data['started_at']).dt.normalize()

# %%
data.head(3)
# Out:
#             ride_id  rideable_type started_at             ended_at  \
# 0  E7CC3B9C2497863F    docked_bike 2020-08-13  2020-08-13 13:55:29
# 1  75F3F6997F82F01C    docked_bike 2020-10-09  2020-10-09 12:47:34
# 2  325DAA770EDE57ED  electric_bike 2020-11-06  2020-11-06 17:46:46
#
#          start_station_name start_station_id         end_station_name  \
# 0  Wells St & Evergreen Ave              291     Paulina St & 18th St
# 1   Streeter Dr & Grand Ave               35  Streeter Dr & Grand Ave
# 2   Sedgwick St & North Ave              118   Damen Ave & Pierce Ave
#
#   end_station_id member_casual day_week_start  duration  distance
# 0            205        member       thrusday    3801.0  59446.72
# 1             35        casual         friday    2085.0      0.00
# 2             69        casual         friday    1140.0  38895.91

# %%
by_date=pd.Series(data['started_at']).value_counts().sort_index()
by_date.index=pd.DatetimeIndex(by_date.index)
data_date=by_date.rename_axis('date').reset_index(name='counts')
data_date
# Out:
#           date  counts
# 0   2020-01-01       2
# 1   2020-01-02       9
# 2   2020-01-03       7
# 3   2020-01-04       1
# 4   2020-01-05       9
# ..         ...     ...
# 524 2021-06-26      29
# 525 2021-06-27      52
# 526 2021-06-28      25
# 527 2021-06-29      31
# 528 2021-06-30      35
#
# [529 rows x 2 columns]
